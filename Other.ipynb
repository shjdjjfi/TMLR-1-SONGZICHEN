# %%
# !git clone https://github.com/computationalprivacy/mia_llms_benchmark.git
# Out:
# Cloning into 'mia_llms_benchmark'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done. Counting objects:  62% (50/80)
# remote: Compressing objects: 100% (52/52), done.
# Receiving objects:  58% (47/80)Receiving objects:  42% (34/80)remote: Total 80 (delta 37), reused 65 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (80/80), 31.62 KiB | 196.00 KiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# !unzip Computo_1.zip
# Out:
# Archive:  Computo_1.zip
# 59e7aafb241b7659daadfacd052692e2209eeb67
#   inflating: .gitignore
#   inflating: conformal.py
#   inflating: data.py
#   inflating: experiments.py
#   inflating: main.py
#   inflating: models.py
#   inflating: plots.py
#   inflating: README_CONFORMAL.md
#   inflating: tables.py
